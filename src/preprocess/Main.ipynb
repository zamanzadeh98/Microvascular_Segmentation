# %% [markdown]
# **This colab notbook is used to run .py files.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append("/content/drive/MyDrive/VesselSegmentation/ZamanPersonalUsage/Codes/Preprocess")

# %% [markdown]
# ### SamplePic.py

# %%
# !python /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/Codes/Preprocess/SamplePic.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/Codes/Preprocess/SamplePic.py", line 18, in <module>
#     with open(jsonPath, "r") as file:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/VesselSegmentation/RawData/polygons.jsonl'

# %% [markdown]
# #### mask_gen.py

# %%
# !python /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/Codes/Preprocess/mask_gen.py
# Out:
# Streaming output truncated to the last 5000 lines.
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# unsure
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# unsure
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# blood_vessel
# ...

# %% [markdown]
# #### Train Test split

# %%
import numpy as np
import glob
import os
import pathlib
import shutil
import shutil
from sklearn.model_selection import train_test_split
import sys

sys.path.append("/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/Codes/Preprocess")

def CopyFunc(Paths, mode):
    """This function copy each images and its corresponding
    mask to train and validation dir
    """
    counter = 0
    # Copying the train images
    for Path_ in Paths:
        try:
            subj = os.path.basename(Path_)

            # Image
            NewImgPath = f"/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/Data/{mode}/image"

            # mask
            #origin
            MaskDir = "/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/masks"


            mask_name = "mask_" + subj[:-4] + ".png"
            mask_path = os.path.join(MaskDir, mask_name)
            # New dir
            NewMaskPath = f"/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/Data/{mode}/mask"

            shutil.copy(mask_path, NewMaskPath)
            shutil.copy(Path_, NewImgPath)

        # If there was no annotation for an image
        # copy it in a folder for later usage
        except:
            NoAnn = "/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/Data/NoAnnotation"
            shutil.copy(Path_, NoAnn)
            counter += 1
            continue
    print(counter)


# if __name__=="__main__":

ImgPaths = glob.glob("/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/*.tif")
print(ImgPaths)
TrainImages, ValImages  = train_test_split(ImgPaths, test_size=0.3, random_state=0)


# Train
CopyFunc(TrainImages, "train")
# Validation
CopyFunc(ValImages, "validation")
# Out:
# ['/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/564283be4af8.tif', '/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/56e1ccd094f2.tif', '/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/55c75331a872.tif', '/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/569a2c83c0b9.tif', '/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/5662056ebcc9.tif', '/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/56cf8fd8e29e.tif', '/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/567abd43c35d.tif', '/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/56fd78b64bea.tif', '/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/56bf4b409647.tif', '/content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/55a1464078dd.tif', '/content/drive/MyDrive/ZamanPersonalUsage/vess
# ...
