# %%
# in order to download the data
# Connect to google drive, first.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kaggle

# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/Codes/Download/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Download the data
# !kaggle competitions download -c hubmap-hacking-the-human-vasculature
# Out:
# ...
# 100% 3.96G/3.97G [01:09<00:00, 76.7MB/s]
# 100% 3.97G/3.97G [01:09<00:00, 61.6MB/s]

# %%
# Unzip the data
# !unzip hubmap-hacking-the-human-vasculature.zip -d /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/48ab0c52f22d.tif
#   inflating: /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/48ad170192e4.tif
#   inflating: /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/48b535ee2927.tif
#   inflating: /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/48bcefbaad54.tif
#   inflating: /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/48bef102863d.tif
#   inflating: /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/48c7d572535a.tif
#   inflating: /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/48cd9932a544.tif
#   inflating: /content/drive/MyDrive/ZamanPersonalUsage/vesselSegmentation/RawData/train/48e32a2aebc0.tif
# ...
